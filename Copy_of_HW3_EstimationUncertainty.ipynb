# %% [markdown]
# <a href="https://colab.research.google.com/github/kelsey-cochran/analysis-of-neural-data/blob/main/Copy_of_HW3_EstimationUncertainty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this homework assignment we will focus on estimation and uncertainty, making use of material from Chapters 6 and 7 from Kass, Eden, and Brown.

# %% [markdown]
# # The law of large numbers and the central limit theorem
#
# Chapter 6 in the textbook introduces the law of large numbers (LLN) and the central limit theorem (CLT). Suppose that we draw some random variables $X_1, X_2, \ldots, X_n$ from some distribution with mean $\mu$ and compute the mean $\bar{X}$, which we expect to be close to but not exactly equal to the true mean $\mu$. The LLN and CLT state the following:
#
# - **LLN**: The sample mean $\bar{X}$ approaches the true mean as $n$ increases.
# - **CLT**: The distribution of $\bar{X}$ becomes normal as $n$ becomes large. This is true even if the distribution of $X$ isn't normal.
#
# In what follows, we will illustrate these two important statistical principles using simulated data for the particular case of binomial distribution.

# %% [markdown]
# ## The binomial distribution
#
# Recall that a binomial distribution describes a sum of binary random variables, and the distribution is characterized by a single parameter $p$. Imagine that we have a (not necessarily fair) coin that comes up heads with probability $p$ and tails with probability $1-p$. We can do an "experiment" in which we flip the coin $n$ times and let $X_i = 1$ if it comes up heads or $X_i = 0$ if it comes up tails on the $i$th flip. We can say that $Y = \sum_{i=1}^n X_i$ is a random variable drawn from a binomial distribution $\mathcal{B}(n,p)$.

# %% [markdown]
# ## LLN for the binomial distribution
#
# The true mean of the binomial distribution is $E(Y) = np$, and the LLN says that $Y$ should get closer and closer to this value as $n$ becomes larger. Our first problem will be to show that this is true by doing a numerical experiment with simulated data, like the coin flip experiment described above.
#
# To begin, we need to figure out how to flip a coin in Python. We can do this using the function `np.random.rand()`, which returns a random value between 0 and 1. If $p$ is the probability that the coin comes up heads, we can simulate a coin flip by saying that the result is heads if `np.random.rand()` $< p$, and tails otherwise. (Think this through to make sure that it makes sense!) Then, if we want to generate a binomial random variable $Y \sim \mathcal{B}(n,p)$, we just need to do this $n$ times and add up the number of heads flips.
#
# The code below shows an example of how this can be done. Since the probability of heads in this example is $p=0.8$ and we are doing 20 flips, we expect the number of heads, `y`, to be about 16:

# %%
p = 0.8
n = 20
y = 0
for i in range(n):
    if np.random.rand() < p:
        y += 1

print(y)
# Out:
# 12

# %% [markdown]
# **Exercise 1**
#
# Turn the above code into a function, `binomial(n,p)` that takes `n` and `p` as arguments and returns a binomial random variable. After writing this function, try printing the result of `binomial(20, 0.8)` and make sure that it gives a reasonable value as in the example above.

# %%
import numpy as np
n = 20
p = 0.8
binomial = lambda n,p: np.random.binomial(n,p)
binomial(n,p)
print(binomial(20,0.8))
# Out:
# 14

# %% [markdown]
# **Exercise 2**
#
# Draw 10000 samples from the binomial distribution with $m=20$ and $p=0.8$ and plot a histogram of the results. Since the random variables are integers, make sure that each bin in the histogram has a width of 1.
#
# **Note**: If you're not confident that you got the previous exercise correct, you can use the built-in function `np.random.binomial()` to generate binomial data in this and the following exercises.

# %%
import numpy as np
import matplotlib.pyplot as plt
m = 20
p = 0.8
n_samples = 10000
samples = np.random.binomial(m, p, size=n_samples)
plt.hist(samples, bins=np.arange(samples.min(), samples.max() +2) - 0.5,
         rwidth=0.8)
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.title("Binomial Distribution (m=20, p=0.8)")
plt.show()

# %% [markdown]
# The LLN says that we expect $\bar{X} = \frac{1}{n} \sum_{i=1}^n X_i$ to get closer and closer to its theoretical mean, $p$, as $n$ increases. For the binomial distribution, where $Y = \sum_{i=1}^n X_i$, this is the same as saying that $Y$ approaches $np$ as $n$ increases.

# %% [markdown]
# **Exercise 3**
#
# Let `n_array = np.array([10, 100, 1000, 10000, 100000])` be an array of values of `n`. Use a `for` loop to print `n` along with $Y/n$ for each value of `n`, where $Y \sim \mathcal{B}(n,p)$ is a binomial random variable. Use $p=0.8$ as above. Do the values get closer to the true mean as `n` gets larger?

# %%
import numpy as np
n_array = np.array([10, 100, 1000, 10000,100000 ])
p = 0.8
for n in n_array:
    y = np.random.binomial(n,p)
    print(n,y/n)
# Out:
# 10 1.0
# 100 0.78
# 1000 0.799
# 10000 0.7949
# 100000 0.80078

# %% [markdown]
# Yes the values get closer to the true mean as n gets larger.

# %% [markdown]
# The above result is intuitive, but it isn't entirely satisfying since, due to randomness, it will give different values each time we run the code. What we really want to know is the *distribution* of $\bar{X}$ for each value of  $n$, since this would give us information about the amount of variability that the sample mean exhibits about the true mean. The CLT gives us this information.

# %% [markdown]
# ## The CLT for the binomial distribution
#
# According to the CLT, the distribution of $\bar{X}$ should become normal as $n$ becomes large. We can see this by plotting a histogram below, in this case with $n=500$.
#
# We can notice two things:
# 1. The distribution looks much more like a normal distribution (i.e. a bell-shaped curve) than the original binomial distribution that we plotted above. This is the crucial point about the CLT: If $n$ is large, then distributions of *means* are normal, even if the distribution from which the data is drawn is not normal. This is very important to keep in mind with experimental data, where the CLT means that we can still know something about the distribution of means, even if we don't know the underlying distribution from which the data is drawn.
# 2. The distribution is very narrowly centered about the true mean, with a small standard deviation. This means that we can expect our estimates of $\bar{X}$ to be very similar if we run the experiment multiple times.

# %%
n = 500
n_samples = 10000
samples = np.zeros(n_samples)
for j in range(n_samples):
    samples[j] = np.random.binomial(n, 0.8)/n

plt.hist(samples, bins=20);
plt.xlabel('y/n')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Regarding the second point above, the full statement of the CLT actually explains this observation. According to the CLT, the distribution of means when $n$ is large is given by $\bar{X} \sim \mathcal{N} (\mu, \sigma^2/n)$, where $\mu$ and $\sigma^2$ are the mean and variance (squared standard deviation) of the distribution over $X$. For a binary variable, these are $\mu = p$ and $\sigma^2 = p(1-p)$. Notice that the variance in the distribution gets smaller as $n$ increases.

# %% [markdown]
# **Exercise 4**
#
# Compute `samples` as above using the following values of `n`: 10, 100, 1000, and 10000. In each case, calculate and print the standard deviation of the values in `samples`, as well as the theoretical value for the standard deviation given above. The values should match to within a few percent. As before, use `n_samples` = 10000 and $p=0.8$.

# %%
import numpy as np
n_array = np.array([10, 100, 1000, 10000])
n_samples = 10000
p = 0.8
for n in n_array:
    samples = np.zeros(n_samples)
    for j in range(n_samples):
        samples[j] = np.random.binomial(n, p)/n
    sample_std = np.std(samples)
    theoretical_std = np.sqrt(p * (1-p) / n)
    print(f"n = {n}:")
    print(f"  Sample Standard Deviation: {sample_std:.4f}")
    print(f"  Theoretical Standard Deviation: {theoretical_std:.4f}")
# Out:
# n = 10:
#   Sample Standard Deviation: 0.1256
#   Theoretical Standard Deviation: 0.1265
# n = 100:
#   Sample Standard Deviation: 0.0399
#   Theoretical Standard Deviation: 0.0400
# n = 1000:
#   Sample Standard Deviation: 0.0126
#   Theoretical Standard Deviation: 0.0126
# n = 10000:
#   Sample Standard Deviation: 0.0039
#   Theoretical Standard Deviation: 0.0040

# %% [markdown]
# # Maximum likelihood
#
# When fitting a statistical model (for example, a normal distribution to describe a collection of data points, or a linear fit to describe the relation between two sets of data) to data, we want to optimize the parameters of the fit. Maximum likelihood (ML) gives us a way to do this. According to ML, we should write think of our data $x$ as coming from a probability distribution $p(x|\theta)$ that depends on parameter $\theta$ (which could be, for example, the mean $\mu$ or variance $\sigma^2$ in a normal distribution). The best value of $\theta$ is then the one that maximizes this probability distribution. In practice, we actually maximize $\ln(p(x|\theta))$ rather than $p(x|\theta)$ itself. We do this because it is easier mathematically, and, since the logarithm always increases when its argument increases, we can be sure that the $\theta$ that maximizes $p(x|\theta)$ will also maximize $\ln(p(x|\theta))$.

# %% [markdown]
# ## ML for the normal distribution
#
# In class, we noted that the probability of observing a data point $x_i$ from a normal distribution is
# $$
# p(x_i | \mu, \sigma) = \frac{1}{\sqrt{2\pi}\sigma} e^{-\frac{1}{2\sigma^2}(x_i - \mu)^2},
# $$
# where $\mu$ and $\sigma$ are the parameters that were referred to as $\theta$ above. If we have lots of independent data points, then the probability of observing all of them is just the product of the individual probabilities:
# $$
# p(x_1, x_2, \ldots, x_n | \mu, \sigma) = \prod_{i=1}^n p(x_i | \mu, \sigma).
# $$
# Then, because the logarithm of a product is equal to the sum of logarithms, the above expression leads to the "log likelihood":
# $$
# \ln p(x_1, x_2, \ldots, x_n | \mu, \sigma) = \sum_{i=1}^n \ln p(x_i | \mu, \sigma)
# = \sum_{i=1}^n \left[ - \ln(\sqrt{2\pi}\sigma) - \frac{(x_i - \mu)^2}{2 \sigma^2}\right].
# $$
# In class we showed that, by setting the derivative of this expression with respect to $\mu$ equal to zero, we could find the optimal value of $\mu$, which we called $\hat{\mu}$:
# $$
# \hat{\mu} = \frac{1}{n} \sum_{i=1}^n x_i,
# $$
# which just says that the normal distribution should be centered at the mean of the data.

# %% [markdown]
# **Exercise 5 (calculation)**
#
# Take the derivative of the above log likelihood with respect to $\sigma$ and set this derivative equal to zero in order to find the optimal value $\hat{\sigma}$. Before you begin, make a guess (just to yourself, no need to write it down) about what you expect the answer to be, then see whether your guess is right. As usual, you can either type your solution using LaTex notation below or submit it as a PDF file. Please show your work.

# %% [markdown]
# # Confidence intervals
#
# Above we considered a coin flipping experiment with $n=10$ flips of a biased coin. If we count an occurrence of heads in flip $i$ as $X_i=1$ and tails as $X_i=0$, then the outcome of our experiment is a random variable $Y = \sum_{i=1}^n X_i$, which is described by a binomial distribution: $Y \sim \mathcal{B}(n,p)$, where $p$ is the true probability of a given flip coming up heads.
#
# Our goal now is to estimate $p$ and to quantify our confidence in that estimate. In class we showed that the maximum likelihood estimate of $p$ for a binomial distribution given data $Y$ is $\hat{p} = Y/n$. The standard error then comes from calculating the variance of this quantity, which we showed in class is $Var(Y/n) = p(1-p)/n$. The standard error is given by the square root of this variance, but with $p$ replaced by our estimate $\hat{p}$ since we don't know the true value of $p$, giving $\text{SE}(\hat{p}) = \sqrt{\hat{p}(1-\hat{p})/n}$.

# %% [markdown]
# The range $[\hat{p}-\text{SE}(\hat{p}), \hat{p}+\text{SE}(\hat{p})]$ can be referred to as a **confidence interval**. If we could repeat our experiment many times and calculate the confidence interval for each experiment, the interval would include, or "cover", the true value of $p$ most of the time (we'll show exactly how often below). (Note that, as we discussed in class, this is slightly different from saying that the true value of $p$ lies inside our confidence interval with a certain probability--a common misinterpretation!) We can also note that the confidence interval becomes smaller as $n$ grows larger, which tells us that we get a better estimate of $p$ as we do more coin flips.
#
# In addition, we can note that we could define a larger confidence interval, for example $[\hat{p}-2\text{SE}(\hat{p}), \hat{p}+2\text{SE}(\hat{p})]$, and we would be more confident that the data lies within this larger interval than within the smaller interval. If, for example, we have a large number of data points $n$ so that the CLT applies, then it is possible to show that the interval $[\hat{p}-2\text{SE}(\hat{p}), \hat{p}+2\text{SE}(\hat{p})]$ is expected to cover the true value of $p$ 95% of the time. Hence, we refer to this as the "95% confidence interval".
#
# It would be difficult to illustrate all of this with real experimental data since it would require having data from a large number of repetitions of the entire experiment. Since we are doing a simulated experiment, though, we can repeat it as many times as we like! In the following exercise, we'll use this ability to illustrate the above statement.

# %% [markdown]
# **Exercise 6**
#
# 1. Use a for loop to repeat the coin flipping experiment with `n=20` and `p=0.8` 10000 times, each time computing $\hat{p}$ and $\text{SE}(\hat{p})$. Print the fraction of the experiments in which the true value of $p$ lies within the confidence interval.

# %%
import numpy as np
n = 20
p = 0.8
n_samples = 10000
covered_count = 0
samples = np.zeros(n_samples)
for j in range(n_samples):
    samples[j] = np.random.binomial(n,p)
    p_hat = samples[j] / n
    se_p_hat = np.sqrt(p_hat * (1-p_hat) / n)
import numpy as np
n = 20
p = 0.8
n_samples = 10000
covered_count = 0
samples = np.zeros(n_samples)
for j in range(n_samples):
    samples[j] = np.random.binomial(n,p)
    p_hat = samples[j] / n
    se_p_hat = np.sqrt(p_hat * (1-p_hat) / n)
    lower_bound = p_hat - 2 * se_p_hat
    upper_bound = p_hat + 2 * se_p_hat
    if lower_bound <= p <= upper_bound:
        covered_count += 1
        fraction_covered = covered_count / n_samples
        print(f"Fraction of experiment where p is covered: {fraction_covered}")
# Out:
# Fraction of experiment where p is covered: 0.0001
# Fraction of experiment where p is covered: 0.0002
# Fraction of experiment where p is covered: 0.0003
# Fraction of experiment where p is covered: 0.0004
# Fraction of experiment where p is covered: 0.0005
# Fraction of experiment where p is covered: 0.0006
# Fraction of experiment where p is covered: 0.0007
# Fraction of experiment where p is covered: 0.0008
# Fraction of experiment where p is covered: 0.0009
# Fraction of experiment where p is covered: 0.001
# Fraction of experiment where p is covered: 0.0011
# Fraction of experiment where p is covered: 0.0012
# Fraction of experiment where p is covered: 0.0013
# Fraction of experiment where p is covered: 0.0014
# Fraction of experiment where p is covered: 0.0015
# Fraction of experiment where p is covered: 0.0016
# Fraction of experiment where p is covered: 0.0017
# Fraction of experiment where p is covered: 0.0018
# Fraction of experiment where p is covered: 0.0019
# Fraction of experiment where p is covered: 0.002
# Fraction of experiment where p is covered: 0.0021
# Fraction of experiment where p is covered: 0.0022
# Fraction of experiment where p is covered: 0.0023
# Fraction of experiment where p is covered: 0.0024
# Fraction of experiment where p is covered: 0.0025
# Fraction of experiment where p is covered: 0.0026
# Fraction of experiment where p is covered: 0.0027
# Fraction of experiment where p is covered: 0.0028
# Fraction of experiment where p is covered: 0.0029
# Fraction of experiment where p is covered: 0.003
# Fraction of experiment where p is covered: 0.0031
# Fraction of experiment where p is covered: 0.0032
# Fraction of experiment where p is covered: 0.0033
# Fraction of experiment where p is covered: 0.0034
# Fraction of experiment where p is covered: 0.0035
# Fraction of experiment where p is covered: 0.0036
# Fraction of experiment where p is covered: 0.0037
# Fraction of experiment where p is covered: 0.0038
# Fraction of experiment where p is covered: 0.0039
# Fraction of experiment where p is covered: 0.004
# Fraction of experiment where p is covered: 0.0041
# Fraction of experiment where p is covered: 0.0042
# Fraction of experiment where p is covered: 0.0043
# Fraction of experiment where p is covered: 0.0044
# Fraction of experiment where p is covered: 0.0045
# Fraction of experiment where p is covered: 0.0046
# Fraction of experiment where p is covered: 0.0047
# Fraction of experiment where p is covered: 0.0048
# Fraction of experiment where p is covered: 0.0049
# Fraction of experiment where p is covered: 0.005
# Fraction of experiment where p is covered: 0.0051
# Fraction of experiment where p is covered: 0.0052
# Fraction of experiment where p is covered: 0.0053
# Fraction of experiment where p is covered: 0.0054
# Fraction of experiment where p is covered: 0.0055
# Fraction of experiment where p is covered: 0.0056
# Fraction of experiment where p is covered: 0.0057
# Fraction of experiment where p is covered: 0.0058
# Fraction of experiment where p is covered: 0.0059
# Fraction of experiment where p is covered: 0.006
# Fraction of experiment where p is covered: 0.0061
# Fraction of experiment where p is covered: 0.0062
# Fraction of experiment where p is covered: 0.0063
# Fraction of experiment where p is covered: 0.0064
# Fraction of experiment where p is covered: 0.0065
# Fraction of experiment where p is covered: 0.0066
# Fraction of experiment where p is covered: 0.0067
# Fraction of experiment where p is covered: 0.0068
# Fraction of experiment where p is covered: 0.0069
# Fraction of experiment where p is covered: 0.007
# Fraction of experiment where p is covered: 0.0071
# Fraction of experiment where p is covered: 0.0072
# Fraction of experiment where p is covered: 0.0073
# Fraction of experiment where p is covered: 0.0074
# Fraction of experiment where p is covered: 0.0075
# Fraction of experiment where p is covered: 0.0076
# Fraction of experiment where p is covered: 0.0077
# Fraction of experiment where p is covered: 0.0078
# Fraction of experiment where p is covered: 0.0079
# Fraction of experiment where p is covered: 0.008
# Fraction of experiment where p is covered: 0.0081
# Fraction of experiment where p is covered: 0.0082
# Fraction of experiment where p is covered: 0.0083
# Fraction of experiment where p is covered: 0.0084
# Fraction of experiment where p is covered: 0.0085
# Fraction of experiment where p is covered: 0.0086
# Fraction of experiment where p is covered: 0.0087
# Fraction of experiment where p is covered: 0.0088
# Fraction of experiment where p is covered: 0.0089
# Fraction of experiment where p is covered: 0.009
# Fraction of experiment where p is covered: 0.0091
# Fraction of experiment where p is covered: 0.0092
# Fraction of experiment where p is covered: 0.0093
# Fraction of experiment where p is covered: 0.0094
# Fraction of experiment where p is covered: 0.0095
# Fraction of experiment where p is covered: 0.0096
# Fraction of experiment where p is covered: 0.0097
# Fraction of experiment where p is covered: 0.0098
# Fraction of experiment where p is covered: 0.0099
# Fraction of experiment where p is covered: 0.01
# Fraction of experiment where p is covered: 0.0101
# Fraction of experiment where p is covered: 0.0102
# Fraction of experiment where p is covered: 0.0103
# Fraction of experiment where p is covered: 0.0104
# Fraction of experiment where p is covered: 0.0105
# Fraction of experiment where p is covered: 0.0106
# Fraction of experiment where p is covered: 0.0107
# Fraction of experiment where p is covered: 0.0108
# Fraction of experiment where p is covered: 0.0109
# Fraction of experiment where p is covered: 0.011
# Fraction of experiment where p is covered: 0.0111
# Fraction of experiment where p is covered: 0.0112
# Fraction of experiment where p is covered: 0.0113
# Fraction of experiment where p is covered: 0.0114
# Fraction of experiment where p is covered: 0.0115
# Fraction of experiment where p is covered: 0.0116
# Fraction of experiment where p is covered: 0.0117
# Fraction of experiment where p is covered: 0.0118
# Fraction of experiment where p is covered: 0.0119
# Fraction of experiment where p is covered: 0.012
# Fraction of experiment where p is covered: 0.0121
# Fraction of experiment where p is covered: 0.0122
# Fraction of experiment where p is covered: 0.0123
# Fraction of experiment where p is covered: 0.0124
# Fraction of experiment where p is covered: 0.0125
# Fraction of experiment where p is covered: 0.0126
# Fraction of experiment where p is covered: 0.0127
# Fraction of experiment where p is covered: 0.0128
# Fraction of experiment where p is covered: 0.0129
# Fraction of experiment where p is covered: 0.013
# Fraction of experiment where p is covered: 0.0131
# Fraction of experiment where p is covered: 0.0132
# Fraction of experiment where p is covered: 0.0133
# Fraction of experiment where p is covered: 0.0134
# Fraction of experiment where p is covered: 0.0135
# Fraction of experiment where p is covered: 0.0136
# Fraction of experiment where p is covered: 0.0137
# Fraction of experiment where p is covered: 0.0138
# Fraction of experiment where p is covered: 0.0139
# Fraction of experiment where p is covered: 0.014
# Fraction of experiment where p is covered: 0.0141
# Fraction of experiment where p is covered: 0.0142
# Fraction of experiment where p is covered: 0.0143
# Fraction of experiment where p is covered: 0.0144
# Fraction of experiment where p is covered: 0.0145
# Fraction of experiment where p is covered: 0.0146
# Fraction of experiment where p is covered: 0.0147
# Fraction of experiment where p is covered: 0.0148
# Fraction of experiment where p is covered: 0.0149
# Fraction of experiment where p is covered: 0.015
# Fraction of experiment where p is covered: 0.0151
# Fraction of experiment where p is covered: 0.0152
# Fraction of experiment where p is covered: 0.0153
# Fraction of experiment where p is covered: 0.0154
# Fraction of experiment where p is covered: 0.0155
# Fraction of experiment where p is covered: 0.0156
# Fraction of experiment where p is covered: 0.0157
# Fraction of experiment where p is covered: 0.0158
# Fraction of experiment where p is covered: 0.0159
# Fraction of experiment where p is covered: 0.016
# Fraction of experiment where p is covered: 0.0161
# Fraction of experiment where p is covered: 0.0162
# Fraction of experiment where p is covered: 0.0163
# Fraction of experiment where p is covered: 0.0164
# Fraction of experiment where p is covered: 0.0165
# Fraction of experiment where p is covered: 0.0166
# Fraction of experiment where p is covered: 0.0167
# Fraction of experiment where p is covered: 0.0168
# Fraction of experiment where p is covered: 0.0169
# Fraction of experiment where p is covered: 0.017
# Fraction of experiment where p is covered: 0.0171
# Fraction of experiment where p is covered: 0.0172
# Fraction of experiment where p is covered: 0.0173
# Fraction of experiment where p is covered: 0.0174
# Fraction of experiment where p is covered: 0.0175
# Fraction of experiment where p is covered: 0.0176
# Fraction of experiment where p is covered: 0.0177
# Fraction of experiment where p is covered: 0.0178
# Fraction of experiment where p is covered: 0.0179
# Fraction of experiment where p is covered: 0.018
# Fraction of experiment where p is covered: 0.0181
# Fraction of experiment where p is covered: 0.0182
# Fraction of experiment where p is covered: 0.0183
# Fraction of experiment where p is covered: 0.0184
# Fraction of experiment where p is covered: 0.0185
# Fraction of experiment where p is covered: 0.0186
# Fraction of experiment where p is covered: 0.0187
# Fraction of experiment where p is covered: 0.0188
# Fraction of experiment where p is covered: 0.0189
# Fraction of experiment where p is covered: 0.019
# Fraction of experiment where p is covered: 0.0191
# Fraction of experiment where p is covered: 0.0192
# Fraction of experiment where p is covered: 0.0193
# Fraction of experiment where p is covered: 0.0194
# Fraction of experiment where p is covered: 0.0195
# Fraction of experiment where p is covered: 0.0196
# Fraction of experiment where p is covered: 0.0197
# Fraction of experiment where p is covered: 0.0198
# Fraction of experiment where p is covered: 0.0199
# Fraction of experiment where p is covered: 0.02
# Fraction of experiment where p is covered: 0.0201
# Fraction of experiment where p is covered: 0.0202
# Fraction of experiment where p is covered: 0.0203
# Fraction of experiment where p is covered: 0.0204
# Fraction of experiment where p is covered: 0.0205
# Fraction of experiment where p is covered: 0.0206
# Fraction of experiment where p is covered: 0.0207
# Fraction of experiment where p is covered: 0.0208
# Fraction of experiment where p is covered: 0.0209
# Fraction of experiment where p is covered: 0.021
# Fraction of experiment where p is covered: 0.0211
# Fraction of experiment where p is covered: 0.0212
# Fraction of experiment where p is covered: 0.0213
# Fraction of experiment where p is covered: 0.0214
# Fraction of experiment where p is covered: 0.0215
# Fraction of experiment where p is covered: 0.0216
# Fraction of experiment where p is covered: 0.0217
# Fraction of experiment where p is covered: 0.0218
# Fraction of experiment where p is covered: 0.0219
# Fraction of experiment where p is covered: 0.022
# Fraction of experiment where p is covered: 0.0221
# Fraction of experiment where p is covered: 0.0222
# Fraction of experiment where p is covered: 0.0223
# Fraction of experiment where p is covered: 0.0224
# Fraction of experiment where p is covered: 0.0225
# Fraction of experiment where p is covered: 0.0226
# Fraction of experiment where p is covered: 0.0227
# Fraction of experiment where p is covered: 0.0228
# Fraction of experiment where p is covered: 0.0229
# Fraction of experiment where p is covered: 0.023
# Fraction of experiment where p is covered: 0.0231
# Fraction of experiment where p is covered: 0.0232
# Fraction of experiment where p is covered: 0.0233
# Fraction of experiment where p is covered: 0.0234
# Fraction of experiment where p is covered: 0.0235
# Fraction of experiment where p is covered: 0.0236
# Fraction of experiment where p is covered: 0.0237
# Fraction of experiment where p is covered: 0.0238
# Fraction of experiment where p is covered: 0.0239
# Fraction of experiment where p is covered: 0.024
# Fraction of experiment where p is covered: 0.0241
# Fraction of experiment where p is covered: 0.0242
# Fraction of experiment where p is covered: 0.0243
# Fraction of experiment where p is covered: 0.0244
# Fraction of experiment where p is covered: 0.0245
# Fraction of experiment where p is covered: 0.0246
# Fraction of experiment where p is covered: 0.0247
# Fraction of experiment where p is covered: 0.0248
# Fraction of experiment where p is covered: 0.0249
# Fraction of experiment where p is covered: 0.025
# Fraction of experiment where p is covered: 0.0251
# Fraction of experiment where p is covered: 0.0252
# Fraction of experiment where p is covered: 0.0253
# Fraction of experiment where p is covered: 0.0254
# Fraction of experiment where p is covered: 0.0255
# Fraction of experiment where p is covered: 0.0256
# Fraction of experiment where p is covered: 0.0257
# Fraction of experiment where p is covered: 0.0258
# Fraction of experiment where p is covered: 0.0259
# Fraction of experiment where p is covered: 0.026
# Fraction of experiment where p is covered: 0.0261
# Fraction of experiment where p is covered: 0.0262
# Fraction of experiment where p is covered: 0.0263
# Fraction of experiment where p is covered: 0.0264
# Fraction of experiment where p is covered: 0.0265
# Fraction of experiment where p is covered: 0.0266
# Fraction of experiment where p is covered: 0.0267
# Fraction of experiment where p is covered: 0.0268
# Fraction of experiment where p is covered: 0.0269
# Fraction of experiment where p is covered: 0.027
# Fraction of experiment where p is covered: 0.0271
# Fraction of experiment where p is covered: 0.0272
# Fraction of experiment where p is covered: 0.0273
# Fraction of experiment where p is covered: 0.0274
# Fraction of experiment where p is covered: 0.0275
# Fraction of experiment where p is covered: 0.0276
# Fraction of experiment where p is covered: 0.0277
# Fraction of experiment where p is covered: 0.0278
# Fraction of experiment where p is covered: 0.0279
# Fraction of experiment where p is covered: 0.028
# Fraction of experiment where p is covered: 0.0281
# Fraction of experiment where p is covered: 0.0282
# Fraction of experiment where p is covered: 0.0283
# Fraction of experiment where p is covered: 0.0284
# Fraction of experiment where p is covered: 0.0285
# Fraction of experiment where p is covered: 0.0286
# Fraction of experiment where p is covered: 0.0287
# Fraction of experiment where p is covered: 0.0288
# Fraction of experiment where p is covered: 0.0289
# Fraction of experiment where p is covered: 0.029
# Fraction of experiment where p is covered: 0.0291
# Fraction of experiment where p is covered: 0.0292
# Fraction of experiment where p is covered: 0.0293
# Fraction of experiment where p is covered: 0.0294
# Fraction of experiment where p is covered: 0.0295
# Fraction of experiment where p is covered: 0.0296
# Fraction of experiment where p is covered: 0.0297
# Fraction of experiment where p is covered: 0.0298
# Fraction of experiment where p is covered: 0.0299
# Fraction of experiment where p is covered: 0.03
# Fraction of experiment where p is covered: 0.0301
# Fraction of experiment where p is covered: 0.0302
# Fraction of experiment where p is covered: 0.0303
# Fraction of experiment where p is covered: 0.0304
# Fraction of experiment where p is covered: 0.0305
# Fraction of experiment where p is covered: 0.0306
# Fraction of experiment where p is covered: 0.0307
# Fraction of experiment where p is covered: 0.0308
# Fraction of experiment where p is covered: 0.0309
# Fraction of experiment where p is covered: 0.031
# Fraction of experiment where p is covered: 0.0311
# Fraction of experiment where p is covered: 0.0312
# Fraction of experiment where p is covered: 0.0313
# Fraction of experiment where p is covered: 0.0314
# Fraction of experiment where p is covered: 0.0315
# Fraction of experiment where p is covered: 0.0316
# Fraction of experiment where p is covered: 0.0317
# Fraction of experiment where p is covered: 0.0318
# Fraction of experiment where p is covered: 0.0319
# Fraction of experiment where p is covered: 0.032
# Fraction of experiment where p is covered: 0.0321
# Fraction of experiment where p is covered: 0.0322
# Fraction of experiment where p is covered: 0.0323
# Fraction of experiment where p is covered: 0.0324
# Fraction of experiment where p is covered: 0.0325
# Fraction of experiment where p is covered: 0.0326
# Fraction of experiment where p is covered: 0.0327
# Fraction of experiment where p is covered: 0.0328
# Fraction of experiment where p is covered: 0.0329
# Fraction of experiment where p is covered: 0.033
# Fraction of experiment where p is covered: 0.0331
# Fraction of experiment where p is covered: 0.0332
# Fraction of experiment where p is covered: 0.0333
# Fraction of experiment where p is covered: 0.0334
# Fraction of experiment where p is covered: 0.0335
# Fraction of experiment where p is covered: 0.0336
# Fraction of experiment where p is covered: 0.0337
# Fraction of experiment where p is covered: 0.0338
# Fraction of experiment where p is covered: 0.0339
# Fraction of experiment where p is covered: 0.034
# Fraction of experiment where p is covered: 0.0341
# Fraction of experiment where p is covered: 0.0342
# Fraction of experiment where p is covered: 0.0343
# Fraction of experiment where p is covered: 0.0344
# Fraction of experiment where p is covered: 0.0345
# Fraction of experiment where p is covered: 0.0346
# Fraction of experiment where p is covered: 0.0347
# Fraction of experiment where p is covered: 0.0348
# Fraction of experiment where p is covered: 0.0349
# Fraction of experiment where p is covered: 0.035
# Fraction of experiment where p is covered: 0.0351
# Fraction of experiment where p is covered: 0.0352
# Fraction of experiment where p is covered: 0.0353
# Fraction of experiment where p is covered: 0.0354
# Fraction of experiment where p is covered: 0.0355
# Fraction of experiment where p is covered: 0.0356
# Fraction of experiment where p is covered: 0.0357
# Fraction of experiment where p is covered: 0.0358
# Fraction of experiment where p is covered: 0.0359
# Fraction of experiment where p is covered: 0.036
# Fraction of experiment where p is covered: 0.0361
# Fraction of experiment where p is covered: 0.0362
# Fraction of experiment where p is covered: 0.0363
# Fraction of experiment where p is covered: 0.0364
# Fraction of experiment where p is covered: 0.0365
# Fraction of experiment where p is covered: 0.0366
# Fraction of experiment where p is covered: 0.0367
# Fraction of experiment where p is covered: 0.0368
# Fraction of experiment where p is covered: 0.0369
# Fraction of experiment where p is covered: 0.037
# Fraction of experiment where p is covered: 0.0371
# Fraction of experiment where p is covered: 0.0372
# Fraction of experiment where p is covered: 0.0373
# Fraction of experiment where p is covered: 0.0374
# Fraction of experiment where p is covered: 0.0375
# Fraction of experiment where p is covered: 0.0376
# Fraction of experiment where p is covered: 0.0377
# Fraction of experiment where p is covered: 0.0378
# Fraction of experiment where p is covered: 0.0379
# Fraction of experiment where p is covered: 0.038
# Fraction of experiment where p is covered: 0.0381
# Fraction of experiment where p is covered: 0.0382
# Fraction of experiment where p is covered: 0.0383
# Fraction of experiment where p is covered: 0.0384
# Fraction of experiment where p is covered: 0.0385
# Fraction of experiment where p is covered: 0.0386
# Fraction of experiment where p is covered: 0.0387
# Fraction of experiment where p is covered: 0.0388
# Fraction of experiment where p is covered: 0.0389
# Fraction of experiment where p is covered: 0.039
# Fraction of experiment where p is covered: 0.0391
# Fraction of experiment where p is covered: 0.0392
# Fraction of experiment where p is covered: 0.0393
# Fraction of experiment where p is covered: 0.0394
# Fraction of experiment where p is covered: 0.0395
# Fraction of experiment where p is covered: 0.0396
# Fraction of experiment where p is covered: 0.0397
# Fraction of experiment where p is covered: 0.0398
# Fraction of experiment where p is covered: 0.0399
# Fraction of experiment where p is covered: 0.04
# Fraction of experiment where p is covered: 0.0401
# Fraction of experiment where p is covered: 0.0402
# Fraction of experiment where p is covered: 0.0403
# Fraction of experiment where p is covered: 0.0404
# Fraction of experiment where p is covered: 0.0405
# Fraction of experiment where p is covered: 0.0406
# Fraction of experiment where p is covered: 0.0407
# Fraction of experiment where p is covered: 0.0408
# Fraction of experiment where p is covered: 0.0409
# Fraction of experiment where p is covered: 0.041
# Fraction of experiment where p is covered: 0.0411
# Fraction of experiment where p is covered: 0.0412
# Fraction of experiment where p is covered: 0.0413
# Fraction of experiment where p is covered: 0.0414
# Fraction of experiment where p is covered: 0.0415
# Fraction of experiment where p is covered: 0.0416
# Fraction of experiment where p is covered: 0.0417
# Fraction of experiment where p is covered: 0.0418
# Fraction of experiment where p is covered: 0.0419
# Fraction of experiment where p is covered: 0.042
# Fraction of experiment where p is covered: 0.0421
# Fraction of experiment where p is covered: 0.0422
# Fraction of experiment where p is covered: 0.0423
# Fraction of experiment where p is covered: 0.0424
# Fraction of experiment where p is covered: 0.0425
# Fraction of experiment where p is covered: 0.0426
# Fraction of experiment where p is covered: 0.0427
# Fraction of experiment where p is covered: 0.0428
# Fraction of experiment where p is covered: 0.0429
# Fraction of experiment where p is covered: 0.043
# Fraction of experiment where p is covered: 0.0431
# Fraction of experiment where p is covered: 0.0432
# Fraction of experiment where p is covered: 0.0433
# Fraction of experiment where p is covered: 0.0434
# Fraction of experiment where p is covered: 0.0435
# Fraction of experiment where p is covered: 0.0436
# Fraction of experiment where p is covered: 0.0437
# Fraction of experiment where p is covered: 0.0438
# Fraction of experiment where p is covered: 0.0439
# Fraction of experiment where p is covered: 0.044
# Fraction of experiment where p is covered: 0.0441
# Fraction of experiment where p is covered: 0.0442
# Fraction of experiment where p is covered: 0.0443
# Fraction of experiment where p is covered: 0.0444
# Fraction of experiment where p is covered: 0.0445
# Fraction of experiment where p is covered: 0.0446
# Fraction of experiment where p is covered: 0.0447
# Fraction of experiment where p is covered: 0.0448
# Fraction of experiment where p is covered: 0.0449
# Fraction of experiment where p is covered: 0.045
# Fraction of experiment where p is covered: 0.0451
# Fraction of experiment where p is covered: 0.0452
# Fraction of experiment where p is covered: 0.0453
# Fraction of experiment where p is covered: 0.0454
# Fraction of experiment where p is covered: 0.0455
# Fraction of experiment where p is covered: 0.0456
# Fraction of experiment where p is covered: 0.0457
# Fraction of experiment where p is covered: 0.0458
# Fraction of experiment where p is covered: 0.0459
# Fraction of experiment where p is covered: 0.046
# Fraction of experiment where p is covered: 0.0461
# Fraction of experiment where p is covered: 0.0462
# Fraction of experiment where p is covered: 0.0463
# Fraction of experiment where p is covered: 0.0464
# Fraction of experiment where p is covered: 0.0465
# Fraction of experiment where p is covered: 0.0466
# Fraction of experiment where p is covered: 0.0467
# Fraction of experiment where p is covered: 0.0468
# Fraction of experiment where p is covered: 0.0469
# Fraction of experiment where p is covered: 0.047
# Fraction of experiment where p is covered: 0.0471
# Fraction of experiment where p is covered: 0.0472
# Fraction of experiment where p is covered: 0.0473
# Fraction of experiment where p is covered: 0.0474
# Fraction of experiment where p is covered: 0.0475
# Fraction of experiment where p is covered: 0.0476
# Fraction of experiment where p is covered: 0.0477
# Fraction of experiment where p is covered: 0.0478
# Fraction of experiment where p is covered: 0.0479
# Fraction of experiment where p is covered: 0.048
# Fraction of experiment where p is covered: 0.0481
# Fraction of experiment where p is covered: 0.0482
# Fraction of experiment where p is covered: 0.0483
# Fraction of experiment where p is covered: 0.0484
# Fraction of experiment where p is covered: 0.0485
# Fraction of experiment where p is covered: 0.0486
# Fraction of experiment where p is covered: 0.0487
# Fraction of experiment where p is covered: 0.0488
# Fraction of experiment where p is covered: 0.0489
# Fraction of experiment where p is covered: 0.049
# Fraction of experiment where p is covered: 0.0491
# Fraction of experiment where p is covered: 0.0492
# Fraction of experiment where p is covered: 0.0493
# Fraction of experiment where p is covered: 0.0494
# Fraction of experiment where p is covered: 0.0495
# Fraction of experiment where p is covered: 0.0496
# Fraction of experiment where p is covered: 0.0497
# Fraction of experiment where p is covered: 0.0498
# Fraction of experiment where p is covered: 0.0499
# Fraction of experiment where p is covered: 0.05
# Fraction of experiment where p is covered: 0.0501
# Fraction of experiment where p is covered: 0.0502
# Fraction of experiment where p is covered: 0.0503
# Fraction of experiment where p is covered: 0.0504
# Fraction of experiment where p is covered: 0.0505
# Fraction of experiment where p is covered: 0.0506
# Fraction of experiment where p is covered: 0.0507
# Fraction of experiment where p is covered: 0.0508
# Fraction of experiment where p is covered: 0.0509
# Fraction of experiment where p is covered: 0.051
# Fraction of experiment where p is covered: 0.0511
# Fraction of experiment where p is covered: 0.0512
# Fraction of experiment where p is covered: 0.0513
# Fraction of experiment where p is covered: 0.0514
# Fraction of experiment where p is covered: 0.0515
# Fraction of experiment where p is covered: 0.0516
# Fraction of experiment where p is covered: 0.0517
# Fraction of experiment where p is covered: 0.0518
# Fraction of experiment where p is covered: 0.0519
# Fraction of experiment where p is covered: 0.052
# Fraction of experiment where p is covered: 0.0521
# Fraction of experiment where p is covered: 0.0522
# Fraction of experiment where p is covered: 0.0523
# Fraction of experiment where p is covered: 0.0524
# Fraction of experiment where p is covered: 0.0525
# Fraction of experiment where p is covered: 0.0526
# Fraction of experiment where p is covered: 0.0527
# Fraction of experiment where p is covered: 0.0528
# Fraction of experiment where p is covered: 0.0529
# Fraction of experiment where p is covered: 0.053
# Fraction of experiment where p is covered: 0.0531
# Fraction of experiment where p is covered: 0.0532
# Fraction of experiment where p is covered: 0.0533
# Fraction of experiment where p is covered: 0.0534
# Fraction of experiment where p is covered: 0.0535
# Fraction of experiment where p is covered: 0.0536
# Fraction of experiment where p is covered: 0.0537
# Fraction of experiment where p is covered: 0.0538
# Fraction of experiment where p is covered: 0.0539
# Fraction of experiment where p is covered: 0.054
# Fraction of experiment where p is covered: 0.0541
# Fraction of experiment where p is covered: 0.0542
# Fraction of experiment where p is covered: 0.0543
# Fraction of experiment where p is covered: 0.0544
# Fraction of experiment where p is covered: 0.0545
# Fraction of experiment where p is covered: 0.0546
# Fraction of experiment where p is covered: 0.0547
# Fraction of experiment where p is covered: 0.0548
# Fraction of experiment where p is covered: 0.0549
# Fraction of experiment where p is covered: 0.055
# Fraction of experiment where p is covered: 0.0551
# Fraction of experiment where p is covered: 0.0552
# Fraction of experiment where p is covered: 0.0553
# Fraction of experiment where p is covered: 0.0554
# Fraction of experiment where p is covered: 0.0555
# Fraction of experiment where p is covered: 0.0556
# Fraction of experiment where p is covered: 0.0557
# Fraction of experiment where p is covered: 0.0558
# Fraction of experiment where p is covered: 0.0559
# Fraction of experiment where p is covered: 0.056
# Fraction of experiment where p is covered: 0.0561
# Fraction of experiment where p is covered: 0.0562
# Fraction of experiment where p is covered: 0.0563
# Fraction of experiment where p is covered: 0.0564
# Fraction of experiment where p is covered: 0.0565
# Fraction of experiment where p is covered: 0.0566
# Fraction of experiment where p is covered: 0.0567
# Fraction of experiment where p is covered: 0.0568
# Fraction of experiment where p is covered: 0.0569
# Fraction of experiment where p is covered: 0.057
# Fraction of experiment where p is covered: 0.0571
# Fraction of experiment where p is covered: 0.0572
# Fraction of experiment where p is covered: 0.0573
# Fraction of experiment where p is covered: 0.0574
# Fraction of experiment where p is covered: 0.0575
# Fraction of experiment where p is covered: 0.0576
# Fraction of experiment where p is covered: 0.0577
# Fraction of experiment where p is covered: 0.0578
# Fraction of experiment where p is covered: 0.0579
# Fraction of experiment where p is covered: 0.058
# Fraction of experiment where p is covered: 0.0581
# Fraction of experiment where p is covered: 0.0582
# Fraction of experiment where p is covered: 0.0583
# Fraction of experiment where p is covered: 0.0584
# Fraction of experiment where p is covered: 0.0585
# Fraction of experiment where p is covered: 0.0586
# Fraction of experiment where p is covered: 0.0587
# Fraction of experiment where p is covered: 0.0588
# Fraction of experiment where p is covered: 0.0589
# Fraction of experiment where p is covered: 0.059
# Fraction of experiment where p is covered: 0.0591
# Fraction of experiment where p is covered: 0.0592
# Fraction of experiment where p is covered: 0.0593
# Fraction of experiment where p is covered: 0.0594
# Fraction of experiment where p is covered: 0.0595
# Fraction of experiment where p is covered: 0.0596
# Fraction of experiment where p is covered: 0.0597
# Fraction of experiment where p is covered: 0.0598
# Fraction of experiment where p is covered: 0.0599
# Fraction of experiment where p is covered: 0.06
# Fraction of experiment where p is covered: 0.0601
# Fraction of experiment where p is covered: 0.0602
# Fraction of experiment where p is covered: 0.0603
# Fraction of experiment where p is covered: 0.0604
# Fraction of experiment where p is covered: 0.0605
# Fraction of experiment where p is covered: 0.0606
# Fraction of experiment where p is covered: 0.0607
# Fraction of experiment where p is covered: 0.0608
# Fraction of experiment where p is covered: 0.0609
# Fraction of experiment where p is covered: 0.061
# Fraction of experiment where p is covered: 0.0611
# Fraction of experiment where p is covered: 0.0612
# Fraction of experiment where p is covered: 0.0613
# Fraction of experiment where p is covered: 0.0614
# Fraction of experiment where p is covered: 0.0615
# Fraction of experiment where p is covered: 0.0616
# Fraction of experiment where p is covered: 0.0617
# Fraction of experiment where p is covered: 0.0618
# Fraction of experiment where p is covered: 0.0619
# Fraction of experiment where p is covered: 0.062
# Fraction of experiment where p is covered: 0.0621
# Fraction of experiment where p is covered: 0.0622
# Fraction of experiment where p is covered: 0.0623
# Fraction of experiment where p is covered: 0.0624
# Fraction of experiment where p is covered: 0.0625
# Fraction of experiment where p is covered: 0.0626
# Fraction of experiment where p is covered: 0.0627
# Fraction of experiment where p is covered: 0.0628
# Fraction of experiment where p is covered: 0.0629
# Fraction of experiment where p is covered: 0.063
# Fraction of experiment where p is covered: 0.0631
# Fraction of experiment where p is covered: 0.0632
# Fraction of experiment where p is covered: 0.0633
# Fraction of experiment where p is covered: 0.0634
# Fraction of experiment where p is covered: 0.0635
# Fraction of experiment where p is covered: 0.0636
# Fraction of experiment where p is covered: 0.0637
# Fraction of experiment where p is covered: 0.0638
# Fraction of experiment where p is covered: 0.0639
# Fraction of experiment where p is covered: 0.064
# Fraction of experiment where p is covered: 0.0641
# Fraction of experiment where p is covered: 0.0642
# Fraction of experiment where p is covered: 0.0643
# Fraction of experiment where p is covered: 0.0644
# Fraction of experiment where p is covered: 0.0645
# Fraction of experiment where p is covered: 0.0646
# Fraction of experiment where p is covered: 0.0647
# Fraction of experiment where p is covered: 0.0648
# Fraction of experiment where p is covered: 0.0649
# Fraction of experiment where p is covered: 0.065
# Fraction of experiment where p is covered: 0.0651
# Fraction of experiment where p is covered: 0.0652
# Fraction of experiment where p is covered: 0.0653
# Fraction of experiment where p is covered: 0.0654
# Fraction of experiment where p is covered: 0.0655
# Fraction of experiment where p is covered: 0.0656
# Fraction of experiment where p is covered: 0.0657
# Fraction of experiment where p is covered: 0.0658
# Fraction of experiment where p is covered: 0.0659
# Fraction of experiment where p is covered: 0.066
# Fraction of experiment where p is covered: 0.0661
# Fraction of experiment where p is covered: 0.0662
# Fraction of experiment where p is covered: 0.0663
# Fraction of experiment where p is covered: 0.0664
# Fraction of experiment where p is covered: 0.0665
# Fraction of experiment where p is covered: 0.0666
# Fraction of experiment where p is covered: 0.0667
# Fraction of experiment where p is covered: 0.0668
# Fraction of experiment where p is covered: 0.0669
# Fraction of experiment where p is covered: 0.067
# Fraction of experiment where p is covered: 0.0671
# Fraction of experiment where p is covered: 0.0672
# Fraction of experiment where p is covered: 0.0673
# Fraction of experiment where p is covered: 0.0674
# Fraction of experiment where p is covered: 0.0675
# Fraction of experiment where p is covered: 0.0676
# Fraction of experiment where p is covered: 0.0677
# Fraction of experiment where p is covered: 0.0678
# Fraction of experiment where p is covered: 0.0679
# Fraction of experiment where p is covered: 0.068
# Fraction of experiment where p is covered: 0.0681
# Fraction of experiment where p is covered: 0.0682
# Fraction of experiment where p is covered: 0.0683
# Fraction of experiment where p is covered: 0.0684
# Fraction of experiment where p is covered: 0.0685
# Fraction of experiment where p is covered: 0.0686
# Fraction of experiment where p is covered: 0.0687
# Fraction of experiment where p is covered: 0.0688
# Fraction of experiment where p is covered: 0.0689
# Fraction of experiment where p is covered: 0.069
# Fraction of experiment where p is covered: 0.0691
# Fraction of experiment where p is covered: 0.0692
# Fraction of experiment where p is covered: 0.0693
# Fraction of experiment where p is covered: 0.0694
# Fraction of experiment where p is covered: 0.0695
# Fraction of experiment where p is covered: 0.0696
# Fraction of experiment where p is covered: 0.0697
# Fraction of experiment where p is covered: 0.0698
# Fraction of experiment where p is covered: 0.0699
# Fraction of experiment where p is covered: 0.07
# Fraction of experiment where p is covered: 0.0701
# Fraction of experiment where p is covered: 0.0702
# Fraction of experiment where p is covered: 0.0703
# Fraction of experiment where p is covered: 0.0704
# Fraction of experiment where p is covered: 0.0705
# Fraction of experiment where p is covered: 0.0706
# Fraction of experiment where p is covered: 0.0707
# Fraction of experiment where p is covered: 0.0708
# Fraction of experiment where p is covered: 0.0709
# Fraction of experiment where p is covered: 0.071
# Fraction of experiment where p is covered: 0.0711
# Fraction of experiment where p is covered: 0.0712
# Fraction of experiment where p is covered: 0.0713
# Fraction of experiment where p is covered: 0.0714
# Fraction of experiment where p is covered: 0.0715
# Fraction of experiment where p is covered: 0.0716
# Fraction of experiment where p is covered: 0.0717
# Fraction of experiment where p is covered: 0.0718
# Fraction of experiment where p is covered: 0.0719
# Fraction of experiment where p is covered: 0.072
# Fraction of experiment where p is covered: 0.0721
# Fraction of experiment where p is covered: 0.0722
# Fraction of experiment where p is covered: 0.0723
# Fraction of experiment where p is covered: 0.0724
# Fraction of experiment where p is covered: 0.0725
# Fraction of experiment where p is covered: 0.0726
# Fraction of experiment where p is covered: 0.0727
# Fraction of experiment where p is covered: 0.0728
# Fraction of experiment where p is covered: 0.0729
# Fraction of experiment where p is covered: 0.073
# Fraction of experiment where p is covered: 0.0731
# Fraction of experiment where p is covered: 0.0732
# Fraction of experiment where p is covered: 0.0733
# Fraction of experiment where p is covered: 0.0734
# Fraction of experiment where p is covered: 0.0735
# Fraction of experiment where p is covered: 0.0736
# Fraction of experiment where p is covered: 0.0737
# Fraction of experiment where p is covered: 0.0738
# Fraction of experiment where p is covered: 0.0739
# Fraction of experiment where p is covered: 0.074
# Fraction of experiment where p is covered: 0.0741
# Fraction of experiment where p is covered: 0.0742
# Fraction of experiment where p is covered: 0.0743
# Fraction of experiment where p is covered: 0.0744
# Fraction of experiment where p is covered: 0.0745
# Fraction of experiment where p is covered: 0.0746
# Fraction of experiment where p is covered: 0.0747
# Fraction of experiment where p is covered: 0.0748
# Fraction of experiment where p is covered: 0.0749
# Fraction of experiment where p is covered: 0.075
# Fraction of experiment where p is covered: 0.0751
# Fraction of experiment where p is covered: 0.0752
# Fraction of experiment where p is covered: 0.0753
# Fraction of experiment where p is covered: 0.0754
# Fraction of experiment where p is covered: 0.0755
# Fraction of experiment where p is covered: 0.0756
# Fraction of experiment where p is covered: 0.0757
# Fraction of experiment where p is covered: 0.0758
# Fraction of experiment where p is covered: 0.0759
# Fraction of experiment where p is covered: 0.076
# Fraction of experiment where p is covered: 0.0761
# Fraction of experiment where p is covered: 0.0762
# Fraction of experiment where p is covered: 0.0763
# Fraction of experiment where p is covered: 0.0764
# Fraction of experiment where p is covered: 0.0765
# Fraction of experiment where p is covered: 0.0766
# Fraction of experiment where p is covered: 0.0767
# Fraction of experiment where p is covered: 0.0768
# Fraction of experiment where p is covered: 0.0769
# Fraction of experiment where p is covered: 0.077
# Fraction of experiment where p is covered: 0.0771
# Fraction of experiment where p is covered: 0.0772
# Fraction of experiment where p is covered: 0.0773
# Fraction of experiment where p is covered: 0.0774
# Fraction of experiment where p is covered: 0.0775
# Fraction of experiment where p is covered: 0.0776
# Fraction of experiment where p is covered: 0.0777
# Fraction of experiment where p is covered: 0.0778
# Fraction of experiment where p is covered: 0.0779
# Fraction of experiment where p is covered: 0.078
# Fraction of experiment where p is covered: 0.0781
# Fraction of experiment where p is covered: 0.0782
# Fraction of experiment where p is covered: 0.0783
# Fraction of experiment where p is covered: 0.0784
# Fraction of experiment where p is covered: 0.0785
# Fraction of experiment where p is covered: 0.0786
# Fraction of experiment where p is covered: 0.0787
# Fraction of experiment where p is covered: 0.0788
# Fraction of experiment where p is covered: 0.0789
# Fraction of experiment where p is covered: 0.079
# Fraction of experiment where p is covered: 0.0791
# Fraction of experiment where p is covered: 0.0792
# Fraction of experiment where p is covered: 0.0793
# Fraction of experiment where p is covered: 0.0794
# Fraction of experiment where p is covered: 0.0795
# Fraction of experiment where p is covered: 0.0796
# Fraction of experiment where p is covered: 0.0797
# Fraction of experiment where p is covered: 0.0798
# Fraction of experiment where p is covered: 0.0799
# Fraction of experiment where p is covered: 0.08
# Fraction of experiment where p is covered: 0.0801
# Fraction of experiment where p is covered: 0.0802
# Fraction of experiment where p is covered: 0.0803
# Fraction of experiment where p is covered: 0.0804
# Fraction of experiment where p is covered: 0.0805
# Fraction of experiment where p is covered: 0.0806
# Fraction of experiment where p is covered: 0.0807
# Fraction of experiment where p is covered: 0.0808
# Fraction of experiment where p is covered: 0.0809
# Fraction of experiment where p is covered: 0.081
# Fraction of experiment where p is covered: 0.0811
# Fraction of experiment where p is covered: 0.0812
# Fraction of experiment where p is covered: 0.0813
# Fraction of experiment where p is covered: 0.0814
# Fraction of experiment where p is covered: 0.0815
# Fraction of experiment where p is covered: 0.0816
# Fraction of experiment where p is covered: 0.0817
# Fraction of experiment where p is covered: 0.0818
# Fraction of experiment where p is covered: 0.0819
# Fraction of experiment where p is covered: 0.082
# Fraction of experiment where p is covered: 0.0821
# Fraction of experiment where p is covered: 0.0822
# Fraction of experiment where p is covered: 0.0823
# Fraction of experiment where p is covered: 0.0824
# Fraction of experiment where p is covered: 0.0825
# Fraction of experiment where p is covered: 0.0826
# Fraction of experiment where p is covered: 0.0827
# Fraction of experiment where p is covered: 0.0828
# Fraction of experiment where p is covered: 0.0829
# Fraction of experiment where p is covered: 0.083
# Fraction of experiment where p is covered: 0.0831
# Fraction of experiment where p is covered: 0.0832
# Fraction of experiment where p is covered: 0.0833
# Fraction of experiment where p is covered: 0.0834
# Fraction of experiment where p is covered: 0.0835
# Fraction of experiment where p is covered: 0.0836
# Fraction of experiment where p is covered: 0.0837
# Fraction of experiment where p is covered: 0.0838
# Fraction of experiment where p is covered: 0.0839
# Fraction of experiment where p is covered: 0.084
# Fraction of experiment where p is covered: 0.0841
# Fraction of experiment where p is covered: 0.0842
# Fraction of experiment where p is covered: 0.0843
# Fraction of experiment where p is covered: 0.0844
# Fraction of experiment where p is covered: 0.0845
# Fraction of experiment where p is covered: 0.0846
# Fraction of experiment where p is covered: 0.0847
# Fraction of experiment where p is covered: 0.0848
# Fraction of experiment where p is covered: 0.0849
# Fraction of experiment where p is covered: 0.085
# Fraction of experiment where p is covered: 0.0851
# Fraction of experiment where p is covered: 0.0852
# Fraction of experiment where p is covered: 0.0853
# Fraction of experiment where p is covered: 0.0854
# Fraction of experiment where p is covered: 0.0855
# Fraction of experiment where p is covered: 0.0856
# Fraction of experiment where p is covered: 0.0857
# Fraction of experiment where p is covered: 0.0858
# Fraction of experiment where p is covered: 0.0859
# Fraction of experiment where p is covered: 0.086
# Fraction of experiment where p is covered: 0.0861
# Fraction of experiment where p is covered: 0.0862
# Fraction of experiment where p is covered: 0.0863
# Fraction of experiment where p is covered: 0.0864
# Fraction of experiment where p is covered: 0.0865
# Fraction of experiment where p is covered: 0.0866
# Fraction of experiment where p is covered: 0.0867
# Fraction of experiment where p is covered: 0.0868
# Fraction of experiment where p is covered: 0.0869
# Fraction of experiment where p is covered: 0.087
# Fraction of experiment where p is covered: 0.0871
# Fraction of experiment where p is covered: 0.0872
# Fraction of experiment where p is covered: 0.0873
# Fraction of experiment where p is covered: 0.0874
# Fraction of experiment where p is covered: 0.0875
# Fraction of experiment where p is covered: 0.0876
# Fraction of experiment where p is covered: 0.0877
# Fraction of experiment where p is covered: 0.0878
# Fraction of experiment where p is covered: 0.0879
# Fraction of experiment where p is covered: 0.088
# Fraction of experiment where p is covered: 0.0881
# Fraction of experiment where p is covered: 0.0882
# Fraction of experiment where p is covered: 0.0883
# Fraction of experiment where p is covered: 0.0884
# Fraction of experiment where p is covered: 0.0885
# Fraction of experiment where p is covered: 0.0886
# Fraction of experiment where p is covered: 0.0887
# Fraction of experiment where p is covered: 0.0888
# Fraction of experiment where p is covered: 0.0889
# Fraction of experiment where p is covered: 0.089
# Fraction of experiment where p is covered: 0.0891
# Fraction of experiment where p is covered: 0.0892
# Fraction of experiment where p is covered: 0.0893
# Fraction of experiment where p is covered: 0.0894
# Fraction of experiment where p is covered: 0.0895
# Fraction of experiment where p is covered: 0.0896
# Fraction of experiment where p is covered: 0.0897
# Fraction of experiment where p is covered: 0.0898
# Fraction of experiment where p is covered: 0.0899
# Fraction of experiment where p is covered: 0.09
# Fraction of experiment where p is covered: 0.0901
# Fraction of experiment where p is covered: 0.0902
# Fraction of experiment where p is covered: 0.0903
# Fraction of experiment where p is covered: 0.0904
# Fraction of experiment where p is covered: 0.0905
# Fraction of experiment where p is covered: 0.0906
# Fraction of experiment where p is covered: 0.0907
# Fraction of experiment where p is covered: 0.0908
# Fraction of experiment where p is covered: 0.0909
# Fraction of experiment where p is covered: 0.091
# Fraction of experiment where p is covered: 0.0911
# Fraction of experiment where p is covered: 0.0912
# Fraction of experiment where p is covered: 0.0913
# Fraction of experiment where p is covered: 0.0914
# Fraction of experiment where p is covered: 0.0915
# Fraction of experiment where p is covered: 0.0916
# Fraction of experiment where p is covered: 0.0917
# Fraction of experiment where p is covered: 0.0918
# Fraction of experiment where p is covered: 0.0919
# Fraction of experiment where p is covered: 0.092
# Fraction of experiment where p is covered: 0.0921
# Fraction of experiment where p is covered: 0.0922
# Fraction of experiment where p is covered: 0.0923
# Fraction of experiment where p is covered: 0.0924
# Fraction of experiment where p is covered: 0.0925
# Fraction of experiment where p is covered: 0.0926
# Fraction of experiment where p is covered: 0.0927
# Fraction of experiment where p is covered: 0.0928
# Fraction of experiment where p is covered: 0.0929
# Fraction of experiment where p is covered: 0.093
# Fraction of experiment where p is covered: 0.0931
# Fraction of experiment where p is covered: 0.0932
# Fraction of experiment where p is covered: 0.0933
# Fraction of experiment where p is covered: 0.0934
# Fraction of experiment where p is covered: 0.0935
# Fraction of experiment where p is covered: 0.0936
# Fraction of experiment where p is covered: 0.0937
# Fraction of experiment where p is covered: 0.0938
# Fraction of experiment where p is covered: 0.0939
# Fraction of experiment where p is covered: 0.094
# Fraction of experiment where p is covered: 0.0941
# Fraction of experiment where p is covered: 0.0942
# Fraction of experiment where p is covered: 0.0943
# Fraction of experiment where p is covered: 0.0944
# Fraction of experiment where p is covered: 0.0945
# Fraction of experiment where p is covered: 0.0946
# Fraction of experiment where p is covered: 0.0947
# Fraction of experiment where p is covered: 0.0948
# Fraction of experiment where p is covered: 0.0949
# Fraction of experiment where p is covered: 0.095
# Fraction of experiment where p is covered: 0.0951
# Fraction of experiment where p is covered: 0.0952
# Fraction of experiment where p is covered: 0.0953
# Fraction of experiment where p is covered: 0.0954
# Fraction of experiment where p is covered: 0.0955
# Fraction of experiment where p is covered: 0.0956
# Fraction of experiment where p is covered: 0.0957
# Fraction of experiment where p is covered: 0.0958
# Fraction of experiment where p is covered: 0.0959
# Fraction of experiment where p is covered: 0.096
# Fraction of experiment where p is covered: 0.0961
# Fraction of experiment where p is covered: 0.0962
# ...
# Fraction of experiment where p is covered: 0.8884
# Fraction of experiment where p is covered: 0.8885
# Fraction of experiment where p is covered: 0.8886
# Fraction of experiment where p is covered: 0.8887
# Fraction of experiment where p is covered: 0.8888
# Fraction of experiment where p is covered: 0.8889
# Fraction of experiment where p is covered: 0.889
# Fraction of experiment where p is covered: 0.8891
# Fraction of experiment where p is covered: 0.8892
# Fraction of experiment where p is covered: 0.8893
# Fraction of experiment where p is covered: 0.8894
# Fraction of experiment where p is covered: 0.8895
# Fraction of experiment where p is covered: 0.8896
# Fraction of experiment where p is covered: 0.8897
# Fraction of experiment where p is covered: 0.8898
# Fraction of experiment where p is covered: 0.8899
# Fraction of experiment where p is covered: 0.89
# Fraction of experiment where p is covered: 0.8901
# Fraction of experiment where p is covered: 0.8902
# Fraction of experiment where p is covered: 0.8903
# Fraction of experiment where p is covered: 0.8904
# Fraction of experiment where p is covered: 0.8905
# Fraction of experiment where p is covered: 0.8906
# Fraction of experiment where p is covered: 0.8907
# Fraction of experiment where p is covered: 0.8908
# Fraction of experiment where p is covered: 0.8909
# Fraction of experiment where p is covered: 0.891
# Fraction of experiment where p is covered: 0.8911
# Fraction of experiment where p is covered: 0.8912
# Fraction of experiment where p is covered: 0.8913
# Fraction of experiment where p is covered: 0.8914
# Fraction of experiment where p is covered: 0.8915
# Fraction of experiment where p is covered: 0.8916
# Fraction of experiment where p is covered: 0.8917
# Fraction of experiment where p is covered: 0.8918
# Fraction of experiment where p is covered: 0.8919
# Fraction of experiment where p is covered: 0.892
# Fraction of experiment where p is covered: 0.8921
# Fraction of experiment where p is covered: 0.8922
# Fraction of experiment where p is covered: 0.8923
# Fraction of experiment where p is covered: 0.8924
# Fraction of experiment where p is covered: 0.8925
# Fraction of experiment where p is covered: 0.8926
# Fraction of experiment where p is covered: 0.8927
# Fraction of experiment where p is covered: 0.8928
# Fraction of experiment where p is covered: 0.8929
# Fraction of experiment where p is covered: 0.893
# Fraction of experiment where p is covered: 0.8931
# Fraction of experiment where p is covered: 0.8932
# Fraction of experiment where p is covered: 0.8933
# Fraction of experiment where p is covered: 0.8934
# Fraction of experiment where p is covered: 0.8935
# Fraction of experiment where p is covered: 0.8936
# Fraction of experiment where p is covered: 0.8937
# Fraction of experiment where p is covered: 0.8938
# Fraction of experiment where p is covered: 0.8939
# Fraction of experiment where p is covered: 0.894
# Fraction of experiment where p is covered: 0.8941
# Fraction of experiment where p is covered: 0.8942
# Fraction of experiment where p is covered: 0.8943
# Fraction of experiment where p is covered: 0.8944
# Fraction of experiment where p is covered: 0.8945
# Fraction of experiment where p is covered: 0.8946
# Fraction of experiment where p is covered: 0.8947
# Fraction of experiment where p is covered: 0.8948
# Fraction of experiment where p is covered: 0.8949
# Fraction of experiment where p is covered: 0.895
# Fraction of experiment where p is covered: 0.8951
# Fraction of experiment where p is covered: 0.8952
# Fraction of experiment where p is covered: 0.8953
# Fraction of experiment where p is covered: 0.8954
# Fraction of experiment where p is covered: 0.8955
# Fraction of experiment where p is covered: 0.8956
# Fraction of experiment where p is covered: 0.8957
# Fraction of experiment where p is covered: 0.8958
# Fraction of experiment where p is covered: 0.8959
# Fraction of experiment where p is covered: 0.896
# Fraction of experiment where p is covered: 0.8961
# Fraction of experiment where p is covered: 0.8962
# Fraction of experiment where p is covered: 0.8963
# Fraction of experiment where p is covered: 0.8964
# Fraction of experiment where p is covered: 0.8965
# Fraction of experiment where p is covered: 0.8966
# Fraction of experiment where p is covered: 0.8967
# Fraction of experiment where p is covered: 0.8968
# Fraction of experiment where p is covered: 0.8969
# Fraction of experiment where p is covered: 0.897
# Fraction of experiment where p is covered: 0.8971
# Fraction of experiment where p is covered: 0.8972
# Fraction of experiment where p is covered: 0.8973
# Fraction of experiment where p is covered: 0.8974
# Fraction of experiment where p is covered: 0.8975
# Fraction of experiment where p is covered: 0.8976
# Fraction of experiment where p is covered: 0.8977
# Fraction of experiment where p is covered: 0.8978
# Fraction of experiment where p is covered: 0.8979
# Fraction of experiment where p is covered: 0.898
# Fraction of experiment where p is covered: 0.8981
# Fraction of experiment where p is covered: 0.8982
# Fraction of experiment where p is covered: 0.8983
# Fraction of experiment where p is covered: 0.8984
# Fraction of experiment where p is covered: 0.8985
# Fraction of experiment where p is covered: 0.8986
# Fraction of experiment where p is covered: 0.8987
# Fraction of experiment where p is covered: 0.8988
# Fraction of experiment where p is covered: 0.8989
# Fraction of experiment where p is covered: 0.899
# Fraction of experiment where p is covered: 0.8991
# Fraction of experiment where p is covered: 0.8992
# Fraction of experiment where p is covered: 0.8993
# Fraction of experiment where p is covered: 0.8994
# Fraction of experiment where p is covered: 0.8995
# Fraction of experiment where p is covered: 0.8996
# Fraction of experiment where p is covered: 0.8997
# Fraction of experiment where p is covered: 0.8998
# Fraction of experiment where p is covered: 0.8999
# Fraction of experiment where p is covered: 0.9
# Fraction of experiment where p is covered: 0.9001
# Fraction of experiment where p is covered: 0.9002
# Fraction of experiment where p is covered: 0.9003
# Fraction of experiment where p is covered: 0.9004
# Fraction of experiment where p is covered: 0.9005
# Fraction of experiment where p is covered: 0.9006
# Fraction of experiment where p is covered: 0.9007
# Fraction of experiment where p is covered: 0.9008
# Fraction of experiment where p is covered: 0.9009
# Fraction of experiment where p is covered: 0.901
# Fraction of experiment where p is covered: 0.9011
# Fraction of experiment where p is covered: 0.9012
# Fraction of experiment where p is covered: 0.9013
# Fraction of experiment where p is covered: 0.9014
# Fraction of experiment where p is covered: 0.9015
# Fraction of experiment where p is covered: 0.9016
# Fraction of experiment where p is covered: 0.9017
# Fraction of experiment where p is covered: 0.9018
# Fraction of experiment where p is covered: 0.9019
# Fraction of experiment where p is covered: 0.902
# Fraction of experiment where p is covered: 0.9021
# Fraction of experiment where p is covered: 0.9022
# Fraction of experiment where p is covered: 0.9023
# Fraction of experiment where p is covered: 0.9024
# Fraction of experiment where p is covered: 0.9025
# Fraction of experiment where p is covered: 0.9026
# Fraction of experiment where p is covered: 0.9027
# Fraction of experiment where p is covered: 0.9028
# Fraction of experiment where p is covered: 0.9029
# Fraction of experiment where p is covered: 0.903
# Fraction of experiment where p is covered: 0.9031
# Fraction of experiment where p is covered: 0.9032
# Fraction of experiment where p is covered: 0.9033
# Fraction of experiment where p is covered: 0.9034
# Fraction of experiment where p is covered: 0.9035
# Fraction of experiment where p is covered: 0.9036
# Fraction of experiment where p is covered: 0.9037
# Fraction of experiment where p is covered: 0.9038
# Fraction of experiment where p is covered: 0.9039
# Fraction of experiment where p is covered: 0.904
# Fraction of experiment where p is covered: 0.9041
# Fraction of experiment where p is covered: 0.9042
# Fraction of experiment where p is covered: 0.9043
# Fraction of experiment where p is covered: 0.9044
# Fraction of experiment where p is covered: 0.9045
# Fraction of experiment where p is covered: 0.9046
# Fraction of experiment where p is covered: 0.9047
# Fraction of experiment where p is covered: 0.9048
# Fraction of experiment where p is covered: 0.9049
# Fraction of experiment where p is covered: 0.905
# Fraction of experiment where p is covered: 0.9051
# Fraction of experiment where p is covered: 0.9052
# Fraction of experiment where p is covered: 0.9053
# Fraction of experiment where p is covered: 0.9054
# Fraction of experiment where p is covered: 0.9055
# Fraction of experiment where p is covered: 0.9056
# Fraction of experiment where p is covered: 0.9057
# Fraction of experiment where p is covered: 0.9058
# Fraction of experiment where p is covered: 0.9059
# Fraction of experiment where p is covered: 0.906
# Fraction of experiment where p is covered: 0.9061
# Fraction of experiment where p is covered: 0.9062
# Fraction of experiment where p is covered: 0.9063
# Fraction of experiment where p is covered: 0.9064
# Fraction of experiment where p is covered: 0.9065
# Fraction of experiment where p is covered: 0.9066
# Fraction of experiment where p is covered: 0.9067
# Fraction of experiment where p is covered: 0.9068
# Fraction of experiment where p is covered: 0.9069
# Fraction of experiment where p is covered: 0.907
# Fraction of experiment where p is covered: 0.9071
# Fraction of experiment where p is covered: 0.9072
# Fraction of experiment where p is covered: 0.9073
# Fraction of experiment where p is covered: 0.9074
# Fraction of experiment where p is covered: 0.9075
# Fraction of experiment where p is covered: 0.9076
# Fraction of experiment where p is covered: 0.9077
# Fraction of experiment where p is covered: 0.9078
# Fraction of experiment where p is covered: 0.9079
# Fraction of experiment where p is covered: 0.908
# Fraction of experiment where p is covered: 0.9081
# Fraction of experiment where p is covered: 0.9082
# Fraction of experiment where p is covered: 0.9083
# Fraction of experiment where p is covered: 0.9084
# Fraction of experiment where p is covered: 0.9085
# Fraction of experiment where p is covered: 0.9086
# Fraction of experiment where p is covered: 0.9087
# Fraction of experiment where p is covered: 0.9088
# Fraction of experiment where p is covered: 0.9089
# Fraction of experiment where p is covered: 0.909
# Fraction of experiment where p is covered: 0.9091
# Fraction of experiment where p is covered: 0.9092
# Fraction of experiment where p is covered: 0.9093
# Fraction of experiment where p is covered: 0.9094
# Fraction of experiment where p is covered: 0.9095
# Fraction of experiment where p is covered: 0.9096
# Fraction of experiment where p is covered: 0.9097
# Fraction of experiment where p is covered: 0.9098
# Fraction of experiment where p is covered: 0.9099
# Fraction of experiment where p is covered: 0.91
# Fraction of experiment where p is covered: 0.9101
# Fraction of experiment where p is covered: 0.9102
# Fraction of experiment where p is covered: 0.9103
# Fraction of experiment where p is covered: 0.9104
# Fraction of experiment where p is covered: 0.9105
# Fraction of experiment where p is covered: 0.9106
# Fraction of experiment where p is covered: 0.9107
# Fraction of experiment where p is covered: 0.9108
# Fraction of experiment where p is covered: 0.9109
# Fraction of experiment where p is covered: 0.911
# Fraction of experiment where p is covered: 0.9111
# Fraction of experiment where p is covered: 0.9112
# Fraction of experiment where p is covered: 0.9113
# Fraction of experiment where p is covered: 0.9114
# Fraction of experiment where p is covered: 0.9115
# Fraction of experiment where p is covered: 0.9116
# Fraction of experiment where p is covered: 0.9117
# Fraction of experiment where p is covered: 0.9118
# Fraction of experiment where p is covered: 0.9119
# Fraction of experiment where p is covered: 0.912
# Fraction of experiment where p is covered: 0.9121
# Fraction of experiment where p is covered: 0.9122
# Fraction of experiment where p is covered: 0.9123
# Fraction of experiment where p is covered: 0.9124
# Fraction of experiment where p is covered: 0.9125
# Fraction of experiment where p is covered: 0.9126
# Fraction of experiment where p is covered: 0.9127
# Fraction of experiment where p is covered: 0.9128
# Fraction of experiment where p is covered: 0.9129
# Fraction of experiment where p is covered: 0.913
# Fraction of experiment where p is covered: 0.9131
# Fraction of experiment where p is covered: 0.9132
# Fraction of experiment where p is covered: 0.9133
# Fraction of experiment where p is covered: 0.9134
# Fraction of experiment where p is covered: 0.9135
# Fraction of experiment where p is covered: 0.9136
# Fraction of experiment where p is covered: 0.9137
# Fraction of experiment where p is covered: 0.9138
# Fraction of experiment where p is covered: 0.9139
# Fraction of experiment where p is covered: 0.914
# Fraction of experiment where p is covered: 0.9141
# Fraction of experiment where p is covered: 0.9142
# Fraction of experiment where p is covered: 0.9143
# Fraction of experiment where p is covered: 0.9144
# Fraction of experiment where p is covered: 0.9145
# Fraction of experiment where p is covered: 0.9146
# Fraction of experiment where p is covered: 0.9147
# Fraction of experiment where p is covered: 0.9148
# Fraction of experiment where p is covered: 0.9149
# Fraction of experiment where p is covered: 0.915
# Fraction of experiment where p is covered: 0.9151
# Fraction of experiment where p is covered: 0.9152
# Fraction of experiment where p is covered: 0.9153
# Fraction of experiment where p is covered: 0.9154
# Fraction of experiment where p is covered: 0.9155
# Fraction of experiment where p is covered: 0.9156
# Fraction of experiment where p is covered: 0.9157
# Fraction of experiment where p is covered: 0.9158
# Fraction of experiment where p is covered: 0.9159
# Fraction of experiment where p is covered: 0.916
# Fraction of experiment where p is covered: 0.9161
# Fraction of experiment where p is covered: 0.9162
# Fraction of experiment where p is covered: 0.9163
# Fraction of experiment where p is covered: 0.9164
# Fraction of experiment where p is covered: 0.9165
# Fraction of experiment where p is covered: 0.9166
# Fraction of experiment where p is covered: 0.9167
# Fraction of experiment where p is covered: 0.9168
# Fraction of experiment where p is covered: 0.9169
# Fraction of experiment where p is covered: 0.917
# Fraction of experiment where p is covered: 0.9171
# Fraction of experiment where p is covered: 0.9172
# Fraction of experiment where p is covered: 0.9173
# Fraction of experiment where p is covered: 0.9174
# Fraction of experiment where p is covered: 0.9175
# Fraction of experiment where p is covered: 0.9176
# Fraction of experiment where p is covered: 0.9177
# Fraction of experiment where p is covered: 0.9178
# Fraction of experiment where p is covered: 0.9179
# Fraction of experiment where p is covered: 0.918
# Fraction of experiment where p is covered: 0.9181
# Fraction of experiment where p is covered: 0.9182
# Fraction of experiment where p is covered: 0.9183
# Fraction of experiment where p is covered: 0.9184
# Fraction of experiment where p is covered: 0.9185
# Fraction of experiment where p is covered: 0.9186
# Fraction of experiment where p is covered: 0.9187
# Fraction of experiment where p is covered: 0.9188
# Fraction of experiment where p is covered: 0.9189
# Fraction of experiment where p is covered: 0.919
# Fraction of experiment where p is covered: 0.9191
# Fraction of experiment where p is covered: 0.9192
# Fraction of experiment where p is covered: 0.9193
# Fraction of experiment where p is covered: 0.9194
# Fraction of experiment where p is covered: 0.9195
# Fraction of experiment where p is covered: 0.9196
# Fraction of experiment where p is covered: 0.9197
# Fraction of experiment where p is covered: 0.9198
# Fraction of experiment where p is covered: 0.9199
# Fraction of experiment where p is covered: 0.92
# Fraction of experiment where p is covered: 0.9201
# Fraction of experiment where p is covered: 0.9202
# Fraction of experiment where p is covered: 0.9203

# %% [markdown]
# 2. Earlier in this notebook we showed how the binomial distribution becomes a normal distribution when $n$ is large due to the CLT. Repeat the previous exercise, but now with `n=500`. Also change the confidence interval to $[\hat{p}-2\text{SE}(\hat{p}), \hat{p}+2\text{SE}(\hat{p})]$. Show that the fraction of experiments in which the confidence interval covers the true value of $p$ is very close to 0.95. This illustrates the "95% rule", which states that, for data that comes from a normal distribution, 95% of the probability is within two standard deviations of the mean. Hence, for a given experiment of $n$ coin flips, we can refer to the range $[\hat{p}-2\text{SE}(\hat{p}), \hat{p}+2\text{SE}(\hat{p})]$ as the "95% confidence interval".

# %%
import numpy as np
n = 500
p = 0.8
n_samples = 10000
samples = np.random.binomial(n, p, size=n_samples)
p_hats = samples / n
se_p_hats = np.sqrt(p_hats * (1 - p_hats) / n)
lower_bounds = p_hats - 2 * se_p_hats
upper_bounds = p_hats + 2 *se_p_hats
within_interval = (lower_bounds <= p) & (upper_bounds >= p)
fraction_covered = np.sum(within_interval) / n_samples
print(f"Fraction of experiment where CI covers true p: {fraction_covered}")
# Out:
# Fraction of experiment where CI covers true p: 0.95

# %% [markdown]
# **Exercise 7**
#
# In class and in the textbook an example was discussed in which a patient with brain damage correctly guessed in 14/17 cases whether a picture of a house was burning, even though she claimed not to be able to see the difference between a burning and non-burning house. Was the patient guessing randomly?
#
# 1. If we model the patient's behavior as a binomial distribution where $p$ is the probability of the patient making a correct guess, compute the interval $[\hat{p}-\text{SE}(\hat{p}), \hat{p}+\text{SE}(\hat{p})]$ and print the estimate as $\hat{p} \pm \text{SE}(\hat{p})$. Does this range include $p=0.5$? If not, this provides evidence that the patient was not randomly guessing.

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 17
successes = 14
p_hat = successes / n
print(f'Point estimate (p-hat): {p_hat:.4f}")')
se_p_hat = np.sqrt(p_hat * (1 - p_hat) / n)
print(f"Standard Error (SE(p-hat)): {se_p_hat:.4f}")
lower_bound = p_hat - se_p_hat
upper_bound = p_hat + se_p_hat
print(f"Confidence Interval: [{lower_bound:.4f}, {upper_bound:.4f}]")
if lower_bound <= 0.5 <= upper_bound:
    print("The confidence interval does not include 0.5")
    print("The patient was not randomly guessing")
else:
    print("The confidence interval includes p=0.5")
    print("The patient was randomly guessing")
# Out:
# Point estimate (p-hat): 0.8235")
# Standard Error (SE(p-hat)): 0.0925
# Confidence Interval: [0.7311, 0.9160]
# The confidence interval includes p=0.5
# The patient was randomly guessing

# %% [markdown]
# 2. Simulate 10000 binomial experiments with $n=17$ and $p=0.5$ and compute $\hat{p}$ for each. In what fraction of the experiments is $\hat{p}$ greater than or equal to the value that you computed above for the patient? This is an example of a "p value" (sorry, this p is different from the other one--p means lots of different things in statistics!). If the p value is small (conventionally, smaller than 0.05 is considered to be significant), this tells us that the observed data is likely to be inconsistent with the statistical model, allowing us to "reject the null hypothesis". The idea of a p value is very important, since it is the typical way that experimental conclusions are stated. We'll learn more about them in the next homework assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 17
p = 0.5
n_samples = 10000
samples = np.random.binomial(n, p, size=n_samples)
p_hats = samples / n
patient_p_hat = 14 / 17
p_value = np.sum(p_hats >= patient_p_hat) / n_samples
print(f"p-value: {p_value}")
# Out:
# p-value: 0.0054

# %% [markdown]
# You should get a value that is well below 0.05, which tells us that it is very unlikely that the patient was randomly guessing.
